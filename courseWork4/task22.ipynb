# %%
import pandas as pd
import numpy as np

sportsCar = pd.read_csv("D:\Python Course work\courseWork4\Sport car price.csv")
print(sportsCar.head())

cleaned_df = sportsCar.dropna()

# %%
cleaned_df.describe
